# %%
import pandas as pd

# %%
profile = ["2026-03-25","최효원","2003-03-12","isfp"]
profile=pd.Series(profile)

profile
# Out:
# 0    2026-03-25
# 1           최효원
# 2    2003-03-12
# 3          isfp
# dtype: object
